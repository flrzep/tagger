# %% [markdown]
# # Inference for YOLO Networks based on Ultralytics

# %%
from IPython import display
display.clear_output()

import os
import glob 

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics 8.3.162  Python-3.13.5 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i5-1345U)
# Setup complete  (12 CPUs, 15.7 GB RAM, 166.9/475.9 GB disk)

# %% [markdown]
# ---
# # V9

# %%
model_path = './runs/segment/train9/weights/best.pt'

# %%
model = YOLO(model_path)

# %%
import importlib
import viewer
importlib.reload(viewer)

img_list = glob.glob(os.path.join("test_images", "*.*"))
img_idx = 6  # change as needed
result = model(img_list[img_idx])[0]
viewer.plot_boxes_on_image_interactive(img_list[img_idx], result)
# Out:
# image 1/1 C:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\test_images\IMG_9130.jpg: 768x1024 21 angle_bars, 330.0ms
# Speed: 43.2ms preprocess, 330.0ms inference, 67.5ms postprocess per image at shape (1, 3, 768, 1024)
# interactive(children=(IntSlider(value=0, description='Box', max=20), Output()), _dom_classes=('widget-interact…

# %% [markdown]
# ---
# # V10
# Run inference on one of the images and display each detection seperately

# %%
model_path = './runs/segment/train10/weights/best.pt'

# %%
model = YOLO(model_path)

# %%
import importlib
import viewer
importlib.reload(viewer)

img_list = glob.glob(os.path.join("test_images", "*.*"))
img_idx = 1  # change as needed
result = model(img_list[img_idx])[0]
viewer.plot_boxes_on_image_interactive(img_list[img_idx], result)
# Out:
# image 1/1 C:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\test_images\00104.png: 576x1024 55 angle_bars, 528.2ms
# Speed: 41.4ms preprocess, 528.2ms inference, 146.2ms postprocess per image at shape (1, 3, 576, 1024)
# interactive(children=(IntSlider(value=0, description='Box', max=50), Output()), _dom_classes=('widget-interact…

# %% [markdown]
# ---
# # V11
# Run inference on one of the images and display each detection seperately

# %%
model_path = './runs/segment/train12/weights/best.pt'

# %%
model = YOLO(model_path)

# %%
import importlib
import viewer
importlib.reload(viewer)

img_list = glob.glob(os.path.join("test_images", "*.*"))
img_idx = 1  # change as needed
result = model(img_list[img_idx])[0]
viewer.plot_boxes_on_image_interactive(img_list[img_idx], result)
# Out:
# image 1/1 C:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\test_images\00104.png: 384x640 56 angle_bars, 116.9ms
# Speed: 6.7ms preprocess, 116.9ms inference, 40.3ms postprocess per image at shape (1, 3, 384, 640)
# interactive(children=(IntSlider(value=0, description='Box', max=50), Output()), _dom_classes=('widget-interact…
