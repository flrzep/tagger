# %% [markdown]
# # Inference for YOLO Networks based on Ultralytics

# %%
from IPython import display
display.clear_output()

import os
import glob 

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics 8.3.162  Python-3.13.5 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i5-1345U)
# Setup complete  (12 CPUs, 15.7 GB RAM, 176.3/475.9 GB disk)

# %% [markdown]
# ---
# # V14

# %%
model_path = './runs/segment/train142/weights/best.pt'

# %%
model = YOLO(model_path)

# %%
import importlib
import viewer
importlib.reload(viewer)

img_list = glob.glob(os.path.join("test_images", "*.*"))
img_idx = 1  # change as needed
result = model(img_list[img_idx])[0]
viewer.plot_boxes_on_image_interactive(img_list[img_idx], result)
# Out:
# image 1/1 c:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\test_images\00104.png: 384x640 2 angle_bars, 211.8ms
# Speed: 3.7ms preprocess, 211.8ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
# interactive(children=(IntSlider(value=0, description='Box', max=1), Output()), _dom_classes=('widget-interact'…

# %% [markdown]
# ---
# # V13
# Run inference on one of the images and display each detection seperately

# %%
model_path = './runs/segment/train122/weights/best.pt'

# %%
model = YOLO(model_path)

# %%
import importlib
import viewer
importlib.reload(viewer)

img_list = glob.glob(os.path.join("test_images", "*.*"))
img_idx = 10  # change as needed
result = model(img_list[img_idx])[0]
viewer.plot_boxes_on_image_interactive(img_list[img_idx], result, box_width=2, fontsize=10)
# Out:
# image 1/1 c:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\test_images\IMG_9266.jpg: 768x1024 5 angle_bars, 541.6ms
# Speed: 10.1ms preprocess, 541.6ms inference, 35.9ms postprocess per image at shape (1, 3, 768, 1024)
# interactive(children=(IntSlider(value=0, description='Box', max=4), Output()), _dom_classes=('widget-interact'…
