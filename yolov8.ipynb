# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger

# %%
from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.161  Python-3.13.5 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i5-1345U)
# Setup complete  (12 CPUs, 15.7 GB RAM, 156.8/475.9 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:02<00:00, 2.91MB/s]
# ...
# 100%|██████████| 104k/104k [00:00<00:00, 794kB/s]
# image 1/1 c:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\dog.jpeg: 640x384 1 person, 1 car, 1 dog, 292.0ms
# Speed: 4.2ms preprocess, 292.0ms inference, 9.7ms postprocess per image at shape (1, 3, 640, 384)

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='.\\test_images\\01.jpg' save=True
# Out:
# c:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger
# Ultralytics 8.3.161  Python-3.13.5 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i5-1345U)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients
#
# image 1/1 c:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\test_images\01.jpg: 480x640 1 tv, 1 laptop, 2 mouses, 1 keyboard, 155.8ms
# Speed: 5.7ms preprocess, 155.8ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
results[0].boxes.xyxy
results[0].boxes.conf
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.])

# %%
# filepath

# Train YOLOv8 on your custom COCO-style dataset using the generated YAML file
# !yolo task=detect mode=train model=yolov8n.pt data="./coco_dataset.yaml" epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.161  Python-3.13.5 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i5-1345U)
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}\\runs\\detect\\train\\confusion_matrix.png', width=600)
# Out:
# c:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 2
#       1 get_ipython().run_line_magic('cd', '{HOME}')
# ----> 2 Image(filename=f'{HOME}\\runs\\detect\\train\\confusion_matrix.png', width=600)
#
# File c:\Users\FLRZ01\AppData\Local\miniconda3\envs\tagger\Lib\site-packages\IPython\core\display.py:1025, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1023 self.unconfined = unconfined
#    1024 self.alt = alt
# -> 1025 super(Image, self).__init__(data=data, url=url, filename=filename,
#    1026         metadata=metadata)
#    1028 if self.width is None and self.metadata.get('width', {}):
#    1029     self.width = metadata['width']
#
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
