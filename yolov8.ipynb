# %%
import os
HOME = os.getcwd()
print(HOME)
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# c:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger

# %%
from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics 8.3.161  Python-3.13.5 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i5-1345U)
# Setup complete  (12 CPUs, 15.7 GB RAM, 157.7/475.9 GB disk)

# %%
# Load a model
# model = YOLO("yolo11n.yaml")  # build a new model from YAML
# model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
# model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights
# model = YOLO('yolov8n.pt')
# model = YOLO('yolov5nu.pt')
model = YOLO("yolo11n-seg.pt")

# %%
# from pathlib import Path

# from ultralytics.data.utils import compress_one_image
# from ultralytics.utils.downloads import zip_directory

# # Define dataset directory
# path = Path("datasets/bars")

# # Optimize images in dataset (optional)
# for f in path.rglob("*.png"):
#     compress_one_image(f)

# # Zip dataset into 'path/to/dataset.zip'
# zip_directory(path)

# %%
# Train the model
results = model.train(data="bars.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.161  Python-3.13.5 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i5-1345U)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=bars.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\segment\train4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    684415  ultralytics.nn.modules.head.Segment          [5, 32, 64, [64, 128, 256]]
# YOLO11n-seg summary: 203 layers, 2,843,583 parameters, 2,843,567 gradients
#
# Transferred 561/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.20.1 ms, read: 111.811.6 MB/s, size: 1950.5 KB)
# train: Scanning C:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\datasets\bars_yolo\labels\train... 14 images, 0 backgrounds, 0 corrupt: 100%|██████████| 14/14 [00:00<00:00, 61.63it/s]
# train: New cache created: C:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\datasets\bars_yolo\labels\train.cache
# val: Fast image access  (ping: 0.10.1 ms, read: 1436.5573.0 MB/s, size: 1968.7 KB)
# c:\Users\FLRZ01\AppData\Local\miniconda3\envs\tagger\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# val: Scanning C:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\datasets\bars_yolo\labels\train.cache... 14 images, 0 backgrounds, 0 corrupt: 100%|██████████| 14/14 [00:00<?, ?it/s]
# Plotting labels to runs\segment\train4\labels.jpg...
# c:\Users\FLRZ01\AppData\Local\miniconda3\envs\tagger\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 90 weight(decay=0.0), 101 weight(decay=0.0005), 100 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\segment\train4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      2.927      4.762      4.254      2.361       1545        640: 100%|██████████| 1/1 [00:47<00:00, 47.79s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.60s/it]
#                    all         14        674    0.00561     0.0089    0.00293   0.000869    0.00374    0.00593    0.00199   0.000199
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G       2.88      4.535       4.28      2.373       1381        640: 100%|██████████| 1/1 [00:16<00:00, 16.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.88s/it]
#                    all         14        674    0.00355    0.00593     0.0019   0.000739    0.00355    0.00593     0.0019    0.00019
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G       2.77      4.366      4.284      2.326       1224        640: 100%|██████████| 1/1 [00:12<00:00, 12.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.73s/it]
#                    all         14        674     0.0034    0.00593    0.00198   0.000627     0.0034    0.00593    0.00183   0.000183
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         0G      2.665      4.253      4.286      2.147       1278        640: 100%|██████████| 1/1 [00:12<00:00, 12.03s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.56s/it]
#                    all         14        674    0.00669     0.0119    0.00375   0.000891    0.00167    0.00297   0.000949   9.49e-05
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       5/100         0G
57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.88s/it]
#                    all         14        674       0.51       0.89      0.795      0.483       0.19      0.332      0.225      0.111
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      87/100         0G      1.231      1.977      1.661      1.096       1162        640: 100%|██████████| 1/1 [00:12<00:00, 12.46s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.62s/it]
#                    all         14        674       0.51       0.89      0.795      0.483       0.19      0.332      0.225      0.111
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      88/100         0G      1.206      2.006      1.648      1.108       1067        640: 100%|██████████| 1/1 [00:12<00:00, 12.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.66s/it]
#                    all         14        674      0.508      0.896      0.797       0.48      0.178      0.315      0.231      0.118
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      89/100         0G      1.202      2.011      1.522      1.103        982        640: 100%|██████████| 1/1 [00:11<00:00, 11.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.67s/it]
#                    all         14        674      0.508      0.896      0.797       0.48      0.178      0.315      0.231      0.118
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      90/100         0G      1.229      2.015      1.546      1.121       1033        640: 100%|██████████| 1/1 [00:11<00:00, 11.78s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.69s/it]
#                    all         14        674      0.508      0.896      0.797       0.48      0.178      0.315      0.231      0.118
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
# c:\Users\FLRZ01\AppData\Local\miniconda3\envs\tagger\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#      91/100         0G      1.346       2.05      1.315      1.215        667        640: 100%|██████████| 1/1 [00:09<00:00,  9.62s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.00s/it]
#                    all         14        674      0.508      0.896      0.797       0.48      0.178      0.315      0.231      0.118
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      92/100         0G      1.451      2.045      1.351      1.277        667        640: 100%|██████████| 1/1 [00:09<00:00,  9.88s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.10s/it]
#                    all         14        674      0.509      0.893      0.802      0.507      0.193      0.338      0.259      0.124
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      93/100         0G      1.426      1.946      1.385      1.284        667        640: 100%|██████████| 1/1 [00:09<00:00,  9.61s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.05s/it]
#                    all         14        674      0.509      0.893      0.802      0.507      0.193      0.338      0.259      0.124
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      94/100         0G      1.291      2.085       1.26      1.165        662        640: 100%|██████████| 1/1 [00:09<00:00,  9.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.97s/it]
#                    all         14        674      0.509      0.893      0.802      0.507      0.193      0.338      0.259      0.124
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      95/100         0G      1.345      2.074      1.287      1.208        666        640: 100%|██████████| 1/1 [00:09<00:00,  9.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.71s/it]
#                    all         14        674      0.509      0.893      0.802      0.507      0.193      0.338      0.259      0.124
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      96/100         0G       1.51      1.936      1.448      1.352        661        640: 100%|██████████| 1/1 [00:09<00:00,  9.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.65s/it]
#                    all         14        674      0.523       0.89      0.823      0.535      0.259       0.27      0.271      0.128
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      97/100         0G      1.397      1.895      1.409      1.269        656        640: 100%|██████████| 1/1 [00:09<00:00,  9.67s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.71s/it]
#                    all         14        674      0.523       0.89      0.823      0.535      0.259       0.27      0.271      0.128
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      98/100         0G      1.273      1.893      1.314      1.205        664        640: 100%|██████████| 1/1 [00:09<00:00,  9.51s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.60s/it]
#                    all         14        674      0.523       0.89      0.823      0.535      0.259       0.27      0.271      0.128
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      99/100         0G        1.2       1.94      1.279      1.152        666        640: 100%|██████████| 1/1 [00:09<00:00,  9.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.69s/it]
#                    all         14        674      0.523       0.89      0.823      0.535      0.259       0.27      0.271      0.128
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     100/100         0G      1.323      1.999      1.304      1.221        664        640: 100%|██████████| 1/1 [00:09<00:00,  9.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.94s/it]
#                    all         14        674      0.523      0.899      0.825      0.543      0.382      0.234      0.281      0.134
# 100 epochs completed in 0.499 hours.
# Optimizer stripped from runs\segment\train4\weights\last.pt, 6.0MB
# Optimizer stripped from runs\segment\train4\weights\best.pt, 6.0MB
#
# Validating runs\segment\train4\weights\best.pt...
# Ultralytics 8.3.161  Python-3.13.5 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i5-1345U)
# YOLO11n-seg summary (fused): 113 layers, 2,835,543 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.10s/it]
#                    all         14        674      0.523      0.899      0.825      0.544      0.385      0.249       0.28      0.133
#              l_profile         14        674      0.523      0.899      0.825      0.544      0.385      0.249       0.28      0.133
# Speed: 1.0ms preprocess, 72.3ms inference, 0.0ms loss, 22.3ms postprocess per image
# Results saved to runs\segment\train4

# %%
# results = model.val(data="coco8.yaml", plots=True)
# print(results.confusion_matrix.to_df())
# Out:
# Ultralytics 8.3.161  Python-3.13.5 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i5-1345U)
# val: Fast image access  (ping: 0.60.6 ms, read: 45.633.9 MB/s, size: 54.0 KB)
# val: Scanning C:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 results = model.val(data="coco8.yaml", plots=True)
#       2 print(results.confusion_matrix.to_df())
#
# File c:\Users\FLRZ01\AppData\Local\miniconda3\envs\tagger\Lib\site-packages\ultralytics\engine\model.py:633, in Model.val(self, validator, **kwargs)
#     630 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     632 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 633 validator(model=self.model)
#     634 self.metrics = validator.metrics
#     635 return validator.metrics
#
# File c:\Users\FLRZ01\AppData\Local\miniconda3\envs\tagger\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\FLRZ01\AppData\Local\miniconda3\envs\tagger\Lib\site-packages\ultralytics\engine\validator.py:221, in BaseValidator.__call__(self, trainer, model)
#     218 with dt[3]:
#     219     preds = self.postprocess(preds)
# --> 221 self.update_metrics(preds, batch)
#     222 if self.args.plots and batch_i < 3:
#     223     self.plot_val_samples(batch, batch_i)
#
# File c:\Users\FLRZ01\AppData\Local\miniconda3\envs\tagger\Lib\site-packages\ultralytics\models\yolo\detect\val.py:183, in DetectionValidator.update_metrics(self, preds, batch)
#     181 for si, pred in enumerate(preds):
#     182     self.seen += 1
# --> 183     pbatch = self._prepare_batch(si, batch)
#     184     predn = self._prepare_pred(pred, pbatch)
#     186     cls = pbatch["cls"].cpu().numpy()
#
# File c:\Users\FLRZ01\AppData\Local\miniconda3\envs\tagger\Lib\site-packages\ultralytics\models\yolo\segment\val.py:133, in SegmentationValidator._prepare_batch(self, si, batch)
#     122 def _prepare_batch(self, si: int, batch: Dict[str, Any]) -> Dict[str, Any]:
#     123     """
#     124     Prepare a batch for training or inference by processing images and targets.
#     125
#    (...)    131         (Dict[str, Any]): Prepared batch with processed annotations.
#     132     """
# --> 133     prepared_batch = super()._prepare_batch(si, batch)
#     134     midx = [si] if self.args.overlap_mask else batch["batch_idx"] == si
#     135     prepared_batch["masks"] = batch["masks"][midx]
#
# File c:\Users\FLRZ01\AppData\Local\miniconda3\envs\tagger\Lib\site-packages\ultralytics\models\yolo\detect\val.py:143, in DetectionValidator._prepare_batch(self, si, batch)
#     132 """
#     133 Prepare a batch of images and annotations for validation.
#     134
#    (...)    140     (Dict[str, Any]): Prepared batch with processed annotations.
#     141 """
#     142 idx = batch["batch_idx"] == si
# --> 143 cls = batch["cls"][idx].squeeze(-1)
#     144 bbox = batch["bboxes"][idx]
#     145 ori_shape = batch["ori_shape"][si]
#
# IndexError: The shape of the mask [17] at index 0 does not match the shape of the indexed tensor [0, 1] at index 0

# %%
# Predict on an image
results = model.predict(source='.\\test_images\\01.jpg', conf=0.25)
# Out:
# image 1/1 c:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\test_images\01.jpg: 480x640 1 tv, 1 laptop, 2 mouses, 1 keyboard, 1 book, 83.7ms
# Speed: 4.9ms preprocess, 83.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Evaluate the model's performance on the validation set
results = model.val()
# Display the confusion matrix as a dataframe
# print(results.confusion_matrix.to_df())
# Out:
# Ultralytics 8.3.161  Python-3.13.5 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i5-1345U)
# val: Fast image access  (ping: 0.20.1 ms, read: 962.3415.1 MB/s, size: 1966.8 KB)
# val: Scanning C:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\datasets\bars_yolo\labels\train.cache... 14 images, 0 backgrounds, 0 corrupt: 100%|██████████| 14/14 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.21s/it]
#                    all         14        674      0.523      0.899      0.825      0.544      0.385      0.249       0.28      0.133
#              l_profile         14        674      0.523      0.899      0.825      0.544      0.385      0.249       0.28      0.133
# Speed: 1.7ms preprocess, 65.1ms inference, 0.0ms loss, 24.5ms postprocess per image
# Results saved to runs\segment\train42

# %%
# Export the model to ONNX format
# needs package 'onnx' installed
success = model.export(format="onnx")
# Out:
# WARNING Retry 1/2 failed: Command 'pip install --no-cache-dir "onnx>=1.12.0,<1.18.0" "onnxslim>=0.1.56" "onnxruntime" ' returned non-zero exit status 1.
# WARNING Retry 2/2 failed: Command 'pip install --no-cache-dir "onnx>=1.12.0,<1.18.0" "onnxslim>=0.1.56" "onnxruntime" ' returned non-zero exit status 1.
# WARNING requirements:  Command 'pip install --no-cache-dir "onnx>=1.12.0,<1.18.0" "onnxslim>=0.1.56" "onnxruntime" ' returned non-zero exit status 1.
#
# ONNX: starting export with onnx 1.18.0 opset 19...
# WARNING ONNX: simplifier failure: No module named 'onnxslim'
# ONNX: export success  324.7s, saved as 'runs\segment\train4\weights\best.onnx' (11.0 MB)
#
# Export complete (325.5s)
# Results saved to C:\Users\FLRZ01\OneDrive - SMS group GmbH\Desktop\dev\tagger\runs\segment\train4\weights
# Predict:         yolo predict task=segment model=runs\segment\train4\weights\best.onnx imgsz=640
# Validate:        yolo val task=segment model=runs\segment\train4\weights\best.onnx imgsz=640 data=bars.yaml
# Visualize:       https://netron.app

# %%
import glob

# get images from a directory as a list
img_list = glob.glob(os.path.join("test_images", "*.*"))
# Run batched inference on a list of images
results = model(img_list)  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# 0: 640x640 (no detections), 116.1ms
# 1: 640x640 (no detections), 116.1ms
# 2: 640x640 (no detections), 116.1ms
# 3: 640x640 (no detections), 116.1ms
# 4: 640x640 (no detections), 116.1ms
# 5: 640x640 (no detections), 116.1ms
# 6: 640x640 (no detections), 116.1ms
# Speed: 3.5ms preprocess, 116.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
